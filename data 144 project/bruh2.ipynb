# %%
import pandas as pd
df = pd.read_json('output.json')

# %%
df
# Out:
#                  business_id                         name  \
# 0     Pns2l4eNsfO8kk83dixA6A     Abby Rappoport, LAC, CMQ
# 1     noByYNtDLQAra9ccqxdfDw                          H&M
# 2     IDtLPgUrqorrpqSLdfMhZQ         Helena Avenue Bakery
# 3     nUqrF-h9S7myCcvNDecOvw         Iron Horse Auto Body
# 4     bYjnX_J1bHZob10DoSFkqQ  Tinkle Belle Diaper Service
# ...                      ...                          ...
# 5198  Bo-GGwQNcLVwyKeYkbfAYg                  Vino Divino
# 5199  8BUr8GviR2o_b-brO21wwQ            Kyle's Isla Vista
# 5200  f7rTfTv6dwO-ovKhz-Rvgw   Joanne & Tem Gronquist, OD
# 5201  uriD7RFuHhLJeDdKaf0nFA                   Pizza Guru
# 5202  JhSByBTYY1rGstRy76YmLA            Reiki with Darren
#
#                       address           city state postal_code   latitude  \
# 0      1616 Chapala St, Ste 2  Santa Barbara    CA       93101  34.426679
# 1            827-833 State St  Santa Barbara    CA       93101  34.420209
# ...
